# %%
import os
from os import listdir
from os.path import isfile, join
import pandas as pd

# %%
folder = 'C:/Users/Scott/CloudStation/Drive/Jupyter/'
folderJHU = 'COVID-19/csse_covid_19_data/csse_covid_19_daily_reports_us/'


# onlyfiles = [f for f in listdir(folder) if isfile(join(folder, f))]

# directory = os.path.join("c:\\","path")
for root,dirs,files in os.walk(folder + folderJHU):
    for file in files:
        if file.endswith(".csv"):
            print(file)
#            f=open(file, 'r')
#            #  perform calculation
#            f.close()

# print(onlyfiles)
# Out:
# 04-12-2020.csv
# 04-13-2020.csv
# 04-14-2020.csv
# 04-15-2020.csv
# 04-16-2020.csv
# 04-17-2020.csv
# 04-18-2020.csv
# 04-19-2020.csv
# 04-20-2020.csv
# 04-21-2020.csv
# 04-22-2020.csv
# 04-23-2020.csv
# 04-24-2020.csv
# 04-25-2020.csv
# 04-26-2020.csv
# 04-27-2020.csv

# %%
folder = 'C:/Users/Scott/CloudStation/Drive/Jupyter/'
folderJHU = 'COVID-19/csse_covid_19_data/csse_covid_19_time_series/'

fileCases = 'time_series_covid19_confirmed_US.csv'
fileDeath = 'time_series_covid19_deaths_US.csv'
# fileRecov = 'time_series_covid19_recovered_global.csv'

dfCases = pd.read_csv(folder + fileCases)
dfDeath = pd.read_csv(folder + fileDeath)
dfRecov = pd.read_csv(folder + fileRecov)

# dfCases.sort_values(by = 'FIPS').head(5)

groupCases = dfCases.groupby('Province_State')
groupDeath = dfDeath.groupby('Province_State')
# groupRecov = dfRecov.groupby('Province_State')

# print(groupCases.groups.keys())

dfJHU = pd.DataFrame(columns = ['date', 'state_name', 'cases', 'deaths', 'recovered'])

for state, group in groupCases:
    print(state)
#     for col in group.columns.values:
        
#         if col[0].isdigit():
#             count = group[col].sum()
#             dfJHU = dfJHU.at
#             print(col  + ': ' + str(count))
#     print()
# Out:
# Alabama
# Alaska
# American Samoa
# Arizona
# Arkansas
# California
# Colorado
# Connecticut
# Delaware
# Diamond Princess
# District of Columbia
# Florida
# Georgia
# Grand Princess
# Guam
# Hawaii
# Idaho
# Illinois
# Indiana
# Iowa
# Kansas
# Kentucky
# Louisiana
# Maine
# Maryland
# Massachusetts
# Michigan
# Minnesota
# Mississippi
# Missouri
# Montana
# Nebraska
# Nevada
# New Hampshire
# New Jersey
# New Mexico
# New York
# North Carolina
# North Dakota
# Northern Mariana Islands
# Ohio
# Oklahoma
# Oregon
# Pennsylvania
# Puerto Rico
# Rhode Island
# South Carolina
# South Dakota
# Tennessee
# Texas
# Utah
# Vermont
# Virgin Islands
# Virginia
# Washington
# West Virginia
# Wisconsin
# Wyoming

# %%
folder = 'C:/Users/Scott/CloudStation/Drive/Jupyter/'
folderJHU = 'COVID-19/csse_covid_19_data/csse_covid_19_daily_reports_us/'

# dfJHU = pd.DataFrame()

for root,dirs,files in os.walk(folder + folderJHU):
    for file in files:
        if file.endswith(".csv"):
#             print(file)
            dfFile = pd.read_csv(folder + folderJHU + file)
            dfFile['date'] = file[0:10]
            dfFile['date'] = pd.to_datetime(dfFile['date'], format = '%m-%d-%Y')
            try:
                dfJHU = pd.merge(dfCombined, dfFile, how ='outer', right_index=True, left_index=True)
            except: # solves problem with merging without matching index values
                dfJHU = dfFile
            
# print(dfFile.columns.values)
# print(dfFile.head(5))

print(dfJHU.columns.values)
print(dfJHU.head(5))
# Out:
# 04-12-2020.csv
# 04-13-2020.csv
# 04-14-2020.csv
# 04-15-2020.csv
# 04-16-2020.csv
# 04-17-2020.csv
# 04-18-2020.csv
# 04-19-2020.csv
# 04-20-2020.csv
# 04-21-2020.csv
# 04-22-2020.csv
# 04-23-2020.csv
# 04-24-2020.csv
# 04-25-2020.csv
# 04-26-2020.csv
# 04-27-2020.csv
# ['Province_State' 'Country_Region' 'Last_Update' 'Lat' 'Long_' 'Confirmed'
#  'Deaths' 'Recovered' 'Active' 'FIPS' 'Incident_Rate' 'People_Tested'
#  'People_Hospitalized' 'Mortality_Rate' 'UID' 'ISO3' 'Testing_Rate'
#  'Hospitalization_Rate' 'date']
#    Province_State Country_Region          Last_Update      Lat     Long_  \
# 0         Alabama             US  2020-04-28 02:32:46  32.3182  -86.9023
# 1          Alaska             US  2020-04-28 02:32:46  61.3707 -152.4044
# 2  American Samoa             US  2020-04-28 02:32:46 -14.2710 -170.1320
# 3         Arizona             US  2020-04-28 02:32:46  33.7298 -111.4312
# 4        Arkansas             US  2020-04-28 02:32:46  34.9697  -92.3731
#
#    Confirmed  Deaths  Recovered  Active  FIPS  Incident_Rate  People_Tested  \
# 0       6539     228        NaN  6311.0   1.0     139.457105        73997.0
# 1        345       9      218.0   336.0   2.0      57.716533        16256.0
# 2          0       0        NaN     NaN  60.0       0.000000            3.0
# 3       6725     275     1418.0  6450.0   4.0      92.392657        66543.0
# 4       3069      51      987.0  3018.0   5.0     118.538741        40457.0
#
#    People_Hospitalized  Mortality_Rate       UID ISO3  Testing_Rate  \
# 0                872.0        3.486772  84000001  USA   1578.132341
# 1                 10.0        2.608696  84000002  USA   2719.536126
# 2                  NaN             NaN        16  ASM      5.391708
# 3               1051.0        4.089219  84000004  USA    914.213315
# 4                109.0        1.661779  84000005  USA   1562.633375
#
#    Hospitalization_Rate       date
# 0             13.335372 2020-04-27
# 1              2.898551 2020-04-27
# 2                   NaN 2020-04-27
# 3             15.628253 2020-04-27
# 4              3.551645 2020-04-27
