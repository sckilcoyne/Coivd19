# %% [markdown]
# # CDC Mortality Data
# Source: https://www.cdc.gov/nchs/data_access/vitalstatsonline.htm

# %%
import pandas as pd

# %%
# from os import listdir

# print(listdir('/Users/Scott/CloudStation/Drive/Jupyter/Covid/CDC Data/'))

dataFolder = '/Users/Scott/CloudStation/Drive/Jupyter/Covid/CDC Data/'
dataFile = 'Mort2018US.PubUse.txt'
print(dataFolder+dataFile)

colspecs = [[19,20],[60,64],[64,66],[68,69],[69,82],[82,83],[83,84],[84,85],
            [101,105],[105,106],[106,107],[107,108],[108,109],[143,144],
            [144,145],[145,162],[162,443],[444,490]]

# colspecs = [[x+1 for x in row] for row in colspecs]

names = ['Resident Status', 'Education', 'Month of Death', 'Sex', 'Reported Age', 
         'Place of Death', 'Marital Status', 'Day of week of Death', 'Data Year', 
        'Injury at Work', 'Manner of death', 'Manner of disposition', 'Autopsy',
        'Activity Code', 'Place of Injury for Causes', 'Underlying Cause of Death', 
        'Multiple conditions', 'Bridged Race']
# Out:
# /Users/Scott/CloudStation/Drive/Jupyter/Covid/CDC Data/Mort2018US.PubUse.txt

# %%
dataFolder = '/Users/Scott/CloudStation/Drive/Jupyter/Covid/CDC Data/'
dataFile = 'Mort2018US.PubUse.txt'
cdcData = pd.read_fwf(dataFolder+dataFile, colspecs=colspecs, header=None, names = names)

cdcData.head(5)
# Out:
#    Resident Status  Education  Month of Death Sex Reported Age  \
# 0                3         31               1   F  1046 351507
# 1                1         31               1   M  1028 311105
# 2                1         61               1   M  1093 442411
# 3                1         21               1   M  1090 442411
# 4                2         41               1   F  1031 321205
#
#    Place of Death Marital Status  Day of week of Death  Data Year  \
# 0               1              D                     2       2018
# 1               7              S                     4       2018
# 2               6              D                     3       2018
# 3               1              W                     7       2018
# 4               1              S                     2       2018
#
#   Injury at Work  Manner of death Manner of disposition Autopsy  \
# 0              U              7.0                     C       N
# ...
