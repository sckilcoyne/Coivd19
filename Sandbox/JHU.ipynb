# %%
import os
from os import listdir
from os.path import isfile, join
import pandas as pd

# %%
folder = 'C:/Users/Scott/CloudStation/Drive/Jupyter/'
folderJHU = 'COVID-19/csse_covid_19_data/csse_covid_19_daily_reports_us/'


# onlyfiles = [f for f in listdir(folder) if isfile(join(folder, f))]

# directory = os.path.join("c:\\","path")
for root,dirs,files in os.walk(folder + folderJHU):
    for file in files:
        if file.endswith(".csv"):
            print(file)
#            f=open(file, 'r')
#            #  perform calculation
#            f.close()

# print(onlyfiles)
# Out:
# 04-12-2020.csv
# 04-13-2020.csv
# 04-14-2020.csv
# 04-15-2020.csv
# 04-16-2020.csv
# 04-17-2020.csv
# 04-18-2020.csv
# 04-19-2020.csv
# 04-20-2020.csv
# 04-21-2020.csv
# 04-22-2020.csv
# 04-23-2020.csv
# 04-24-2020.csv
# 04-25-2020.csv
# 04-26-2020.csv
# 04-27-2020.csv

# %%
folder = 'C:/Users/Scott/CloudStation/Drive/Jupyter/'
folderJHU = 'COVID-19/csse_covid_19_data/csse_covid_19_time_series/'

fileCases = 'time_series_covid19_confirmed_US.csv'
fileDeath = 'time_series_covid19_deaths_US.csv'
# fileRecov = 'time_series_covid19_recovered_global.csv'

dfCases = pd.read_csv(folder + fileCases)
dfDeath = pd.read_csv(folder + fileDeath)
dfRecov = pd.read_csv(folder + fileRecov)

# dfCases.sort_values(by = 'FIPS').head(5)

groupCases = dfCases.groupby('Province_State')
groupDeath = dfDeath.groupby('Province_State')
# groupRecov = dfRecov.groupby('Province_State')

# print(groupCases.groups.keys())

dfJHU = pd.DataFrame(columns = ['date', 'state_name', 'cases', 'deaths', 'recovered'])

for state, group in groupCases:
    print(state)
#     for col in group.columns.values:
        
#         if col[0].isdigit():
#             count = group[col].sum()
#             dfJHU = dfJHU.at
#             print(col  + ': ' + str(count))
#     print()
# Out:
# Alabama
# Alaska
# American Samoa
# Arizona
# Arkansas
# California
# Colorado
# Connecticut
# Delaware
# Diamond Princess
# District of Columbia
# Florida
# Georgia
# Grand Princess
# Guam
# Hawaii
# Idaho
# Illinois
# Indiana
# Iowa
# Kansas
# Kentucky
# Louisiana
# Maine
# Maryland
# Massachusetts
# Michigan
# Minnesota
# Mississippi
# Missouri
# Montana
# Nebraska
# Nevada
# New Hampshire
# New Jersey
# New Mexico
# New York
# North Carolina
# North Dakota
# Northern Mariana Islands
# Ohio
# Oklahoma
# Oregon
# Pennsylvania
# Puerto Rico
# Rhode Island
# South Carolina
# South Dakota
# Tennessee
# Texas
# Utah
# Vermont
# Virgin Islands
# Virginia
# Washington
# West Virginia
# Wisconsin
# Wyoming

# %%
folder = 'C:/Users/Scott/CloudStation/Drive/Jupyter/'
folderJHU = 'COVID-19/csse_covid_19_data/csse_covid_19_daily_reports_us/'

removeCols = ['Province_State', 'Country_Region', 'Last_Update', 'Lat', 'Long_',
              'Mortality_Rate', 'UID', 'ISO3', 'Testing_Rate', 'Hospitalization_Rate']

dfJHU = pd.DataFrame()

for root,dirs,files in os.walk(folder + folderJHU):
    for file in files:
        if file.endswith(".csv"):
#             print(file)
            dfFile = pd.read_csv(folder + folderJHU + file)
            dfFile['date'] = file[0:10]
            dfFile['date'] = pd.to_datetime(dfFile['date'], format = '%m-%d-%Y')
            
            try:
                dfJHU = pd.concat([dfJHU, dfFile])
            except: # solves problem with merging without matching index values
                dfJHU = dfFile
            
# Removed Extra Columns
dfJHU = dfJHU.drop(removeCols, axis=1, errors = 'ignore')
# Convert fips to str
dfJHU['fips'] = dfJHU['FIPS'].apply(str)
dfJHU = dfJHU.drop('FIPS', axis=1, errors = 'ignore')

cols = dfJHU.columns.values
#  Move date to first column
removeDate = np.add(np.where(cols == 'date'), 1)
cols = np.insert(cols,0,'date')
cols = np.delete(cols, removeDate)
dfJHU = dfJHU[cols]  
#  Move fips to second column
removeFIPS = np.add(np.where(cols == 'fips'), 1)
cols = np.insert(cols,1,'fips')
cols = np.delete(cols, removeFIPS)
dfJHU = dfJHU[cols]


# print(dfFile.columns.values)
# print(dfFile.head(5))

print(dfJHU.columns.values)
# print(dfJHU.head(5))
# Out:
# ['date' 'fips' 'Confirmed' 'Deaths' 'Recovered' 'Active' 'Incident_Rate'
#  'People_Tested' 'People_Hospitalized']
